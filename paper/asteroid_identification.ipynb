# %%
import warnings

warnings.filterwarnings("ignore", module="erfa")

import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.time import Time

from jorbit.mpchecker import mpchecker

mpchecker(
    coordinate=SkyCoord(125.7398*u.deg, 18.7334*u.deg),
    time=Time("2021-10-13 01:24"),
    radius=3*u.arcmin,
    extra_precision=False,
)
# Out:
# <Table length=2>
#   Unpacked Name       separation             ra         ... Flags last obs
#                         arcsec              deg         ...
#       str17            float64            float64       ...  str4   str8
# ----------------- ------------------ ------------------ ... ----- --------
# (42623) 1998 FT27  130.2434084303274 125.70309881642234 ...  0000 20250216
#     (20) Massalia 138.55815494614683 125.75966750487092 ...  0000 20250220

# %%
import warnings

warnings.filterwarnings("ignore", module="erfa")

import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.time import Time

from jorbit.mpchecker import mpchecker

mpchecker(
    coordinate=SkyCoord(125.7398*u.deg, 18.7334*u.deg),
    time=Time("2021-10-13 01:24"),
    radius=3*u.arcmin,
    extra_precision=True,
    extra_precision_gravity="default solar system",
    observer="Kitt Peak"
)
# Out:
# <Table length=2>
#   Unpacked Name       separation             ra         ... Flags last obs
#                         arcsec              deg         ...
#       str17            float64            float64       ...  str4   str8
# ----------------- ------------------ ------------------ ... ----- --------
# (42623) 1998 FT27 130.27855512855862 125.70285800730863 ...  0000 20250216
#     (20) Massalia 140.94581208780525 125.75939363108915 ...  0000 20250220

# %%
m = mpchecker(
    coordinate=SkyCoord(125.7398*u.deg, 18.7334*u.deg),
    time=Time("2021-10-13 01:24"),
    radius=3*u.arcmin,
    extra_precision=True,
    extra_precision_gravity="default solar system",
    observer="Kitt Peak"
)
SkyCoord(m['ra'], m['dec'], unit='deg').to_string('hmsdms', sep=':')
# Out:
# ['08:22:48.68592175 +18:44:33.57233696',
#  '08:23:02.25447146 +18:41:56.13303307']

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from jorbit.mpchecker.parse_jorbit_ephem import load_mpcorb

mp = load_mpcorb()

# %%
import polars as pl

mp.filter(pl.col("Packed designation") == "~0JdU")
# Out:
# shape: (1, 23)
# ┌────────────────────┬───────┬──────┬───────┬───┬──────────┬───────┬───────────────┬──────────┐
# │ Packed designation ┆ H     ┆ G    ┆ Epoch ┆ … ┆ Computer ┆ Flags ┆ Unpacked Name ┆ last obs │
# │ ---                ┆ ---   ┆ ---  ┆ ---   ┆   ┆ ---      ┆ ---   ┆ ---           ┆ ---      │
# │ str                ┆ str   ┆ str  ┆ str   ┆   ┆ str      ┆ str   ┆ str           ┆ str      │
# ╞════════════════════╪═══════╪══════╪═══════╪═══╪══════════╪═══════╪═══════════════╪══════════╡
# │ ~0JdU              ┆ 17.18 ┆ 0.15 ┆ K2555 ┆ … ┆ MPCLINUX ┆ 0000  ┆ (695484) 2015 ┆ 20230425 │
# │                    ┆       ┆      ┆       ┆   ┆          ┆       ┆ XB347         ┆          │
# └────────────────────┴───────┴──────┴───────┴───┴──────────┴───────┴───────────────┴──────────┘

# %% [markdown]
# ![image.png](attachment:image.png)
